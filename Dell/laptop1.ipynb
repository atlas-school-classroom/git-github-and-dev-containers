# %%
print("Name: David Smith")
# Out:
# Name: David Smith

# %%
class Person:
    def __init__(self, Name, age, city):
        self.name = Name
        self.age = age
        self.city = city

person1 = Person("David Smith", 30, "New York")
print("Name:", person1.name)
print("Age:", person1.age)
print("City:", person1.city)
# Out:
# Name: David Smith
# Age: 30
# City: New York

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class BinarySearchTree:
    def __init__(self):
        self.root = None

    def insert(self, value):
        if self.root is None:
            self.root = Node(value)
        else:
